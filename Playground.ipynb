# %%
import matplotlib.image as mpimg
import os
from PIL import Image

image_names = os.listdir("Signs/")
new_dims = np.array([[100,324,751,975],[462,1230,15,783],[73,777,373,1077],[175,975,35,835],[0,450,45,510]])

nd = np.copy(new_dims)
class_names = '50km/h','Double curve','20km/h','Yield','Road work'
file_names = '50kmh','Double_curve','20kmh','Yield', 'Road_work'
class_ids = [2,21,0,13,25]


for i in range(len(image_names)):
    img = mpimg.imread('Signs/{}'.format(image_names[i]))
    img = img[nd[i][0]:nd[i][1],nd[i][2]:nd[i][3]]
    plt.imshow(img)
    plt.show()
    print(img.shape)
# Out:
# (224, 224, 3)
# (768, 768, 3)
# (704, 704, 3)
# (800, 800, 3)
# (450, 465, 3)

# %%
mult_32 = 32*np.array(range(6,30))
print(mult_32)
from PIL import Image
r = [751,100,975,324],[15,462,783,1230],[373,73,1077,777],[35,175,835,975],[45,0,510,450]
for i in range(5):
    img = Image.open('Signs/{}'.format(image_names[i]))
    img = img.crop(r[i])
    plt.imshow(img)
    plt.show()
    img2 = img.resize((32,32),Image.LANCZOS)
    plt.imshow(img2)
    plt.show()
    img2.save("ResizedSigns/" + file_names[i] + "_thumbnail.jpg","JPEG")
# Out:
# [192 224 256 288 320 352 384 416 448 480 512 544 576 608 640 672 704 736
#  768 800 832 864 896 928]
